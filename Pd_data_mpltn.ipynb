# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn; seaborn.set()

# %%
data = pd.read_csv('/home/moyi/president_heights.csv')
heights = np.array(data['height(cm)'])
print(heights)
# Out:
# [189 170 189 163 183 171 185 168 173 183 173 173 175 178 183 193 178 173
#  174 183 183 168 170 178 182 180 183 178 182 188 175 179 183 193 182 183
#  177 185 188 188 182 185]

# %%
plt.hist(heights)
plt.title('Height Distribution of US Presidents')
plt.xlabel('height(cm)')
plt.ylabel('number')
# Out:
# Text(0, 0.5, 'number')

# %%
a = np.array([0,1, 2])
b = np.array([5, 5, 5])
M = np.ones((3, 3))

# %%
M
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
a + b
a + 5
M + a
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.],
#        [1., 2., 3.]])

# %%
X = np.random.random((10, 3))
X
# Out:
# array([[0.64258912, 0.67954078, 0.57545476],
#        [0.30036072, 0.97331577, 0.64248424],
#        [0.51555958, 0.58461275, 0.30507297],
#        [0.2165744 , 0.14590821, 0.06760238],
#        [0.49017419, 0.97868176, 0.70528605],
#        [0.27766049, 0.23305797, 0.43320375],
#        [0.92801582, 0.22403659, 0.4424718 ],
#        [0.37715402, 0.84884731, 0.66306487],
#        [0.62529688, 0.1733075 , 0.62265803],
#        [0.70092461, 0.57709743, 0.54546879]])

# %%
Xmean = X.mean(0)
Xmean
# Out:
# array([0.50743098, 0.54184061, 0.50027676])

# %%
X_centered = X - Xmean

# %%
X_centered.mean(0)
# Out:
# array([ 1.55431223e-16, -2.22044605e-17,  2.22044605e-17])

# %%
# x and y have 50 steps from 0 to 5
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 50)[:, np.newaxis]

z = np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
plt.imshow(z, origin='lower', extent=[0, 5, 0, 5], cmap='viridis')
plt.colorbar;
